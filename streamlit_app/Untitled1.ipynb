# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install -q streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 88.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 86.4 MB/s eta 0:00:00

# %%
import streamlit

# %%
from pathlib import Path

PROJECT_ROOT = Path(
    "/content/drive/MyDrive/2026/comento/week4"
)

STREAMLIT_ROOT = (
    PROJECT_ROOT
    / "streamlit_app"
)

# %%
import sys

if str(STREAMLIT_ROOT) not in sys.path:
    sys.path.insert(
        0,
        str(STREAMLIT_ROOT),
    )

import config as app_config

print("Checkpoint:", app_config.CHECKPOINT_PATH)
print("Exists    :", app_config.CHECKPOINT_PATH.exists())
# Out:
# Checkpoint: /content/drive/MyDrive/2026/comento/week4/checkpoints/finetuning/best_model.pt
# Exists    : True

# %%
from google.colab import output

output.serve_kernel_port_as_iframe(
    8501,
    height=1100,
)
